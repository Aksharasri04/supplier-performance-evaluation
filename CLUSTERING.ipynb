# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import numpy as np

# %%
data = pd.read_csv('pca.csv')
data
# Out:
#       Line Item Quantity  Line Item Value  Pack Price  Unit Price  \
# 0              -0.444078        -0.435110   -0.543259   -0.241211
# 1              -0.460221        -0.434236    3.385274    0.303203
# 2              -0.454292        -0.435123   -0.543259   -0.241211
# 3              -0.460122        -0.433826    1.364619   -0.143295
# 4              -0.445324        -0.432329   -0.502558   -0.237295
# ...                  ...              ...         ...         ...
# 6996           -0.459698        -0.434958   -0.477685   -0.225545
# 6997           -0.459698        -0.434958   -0.477685   -0.225545
# 6998           -0.435259        -0.407649   -0.303291   -0.225545
# 6999           -0.459648        -0.434587   -0.352472   -0.198128
# 7000           -0.460196        -0.434822    0.360934    0.385452
#
#       LineItemInsurance
# 0             -0.457077
# 1             -0.456132
# 2             -0.457099
# 3             -0.455671
# 4             -0.454044
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D

k_2 = KMeans(n_clusters=2, random_state=42)
k_2.fit(data)  
labels_2 = k_2.labels_
score_2 = silhouette_score(data, labels_2)  
centroids_2 = k_2.cluster_centers_

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(data.iloc[:, 0], data.iloc[:, 1], data.iloc[:, 2], c=labels_2, cmap='viridis', marker='o', s=50)
ax.scatter(centroids_2[:, 0], centroids_2[:, 1], centroids_2[:, 2], c='red', marker='X', s=200, label='Centroids')


ax.set_title('K-Means Clustering with k=2 (3D)')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')
ax.legend()
plt.show()

plt.figure(figsize=(8, 6))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=labels_2, cmap='viridis', marker='o', s=50)
plt.scatter(centroids_2[:, 0], centroids_2[:, 1], c='red', marker='X', s=200, label='Centroids')
plt.title('K-Means Clustering with k=2')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()

print(f"Silhouette Score for k=2: {score_2}")
# Out:
# Silhouette Score for k=2: 0.8170870000285667

# %%
k_3 = KMeans(n_clusters=3, random_state=42)
k_3.fit(data) 
labels_3 = k_3.labels_
score_3 = silhouette_score(data, labels_3) 
centroids_3 = k_3.cluster_centers_

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data.iloc[:, 0], data.iloc[:, 1], data.iloc[:, 2], c=labels_3, cmap='viridis', marker='o', s=50)
ax.scatter(centroids_3[:, 0], centroids_3[:, 1], centroids_3[:, 2], c='red', marker='X', s=200, label='Centroids')
ax.set_title('K-Means Clustering with k=3 (3D)')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')
ax.legend()
plt.show()

plt.figure(figsize=(8, 6))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=labels_3, cmap='viridis', marker='o', s=50)
plt.scatter(centroids_3[:, 0], centroids_3[:, 1], c='red', marker='X', s=200, label='Centroids')
plt.title('K-Means Clustering with k=3')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()

print(f"Silhouette Score for k=3: {score_3}")
# Out:
# Silhouette Score for k=3: 0.7297960824560046

# %%
k_4 = KMeans(n_clusters=4, random_state=42)
k_4.fit(data)  
labels_4 = k_4.labels_
score_4 = silhouette_score(data, labels_4)  
centroids_4 = k_4.cluster_centers_

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data.iloc[:, 0], data.iloc[:, 1], data.iloc[:, 2], c=labels_4, cmap='viridis', marker='o', s=50)
ax.scatter(centroids_4[:, 0], centroids_4[:, 1], centroids_4[:, 2], c='red', marker='X', s=200, label='Centroids')

ax.set_title('K-Means Clustering with k=4 (3D)')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')
ax.legend()
plt.show()
plt.figure(figsize=(8, 6))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=labels_4, cmap='viridis', marker='o', s=50)
plt.scatter(centroids_4[:, 0], centroids_4[:, 1], c='red', marker='X', s=200, label='Centroids')
plt.title('K-Means Clustering with k=4')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()

print(f"Silhouette Score for k=4: {score_4}")
# Out:
# Silhouette Score for k=4: 0.6459308374788388

# %%
k_5 = KMeans(n_clusters=5, random_state=42)
k_5.fit(data) 
labels_5 = k_5.labels_
score_5 = silhouette_score(data, labels_5) 
centroids_5 = k_5.cluster_centers_
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(data.iloc[:, 0], data.iloc[:, 1], data.iloc[:, 2], c=labels_5, cmap='viridis', marker='o', s=50)
ax.scatter(centroids_5[:, 0], centroids_5[:, 1], centroids_5[:, 2], c='red', marker='X', s=200, label='Centroids')
ax.set_title('K-Means Clustering with k=5 (3D)')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')
ax.legend()
plt.show()
print(f"Silhouette Score for k=5: {score_5}")
# Out:
# Silhouette Score for k=5: 0.6679767386759573

# %%
k_6 = KMeans(n_clusters=6, random_state=42)
k_6.fit(data) 
labels_6 = k_6.labels_
score_6 = silhouette_score(data, labels_6)  
centroids_6 = k_6.cluster_centers_

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data.iloc[:, 0], data.iloc[:, 1], data.iloc[:, 2], c=labels_6, cmap='viridis', marker='o', s=50)
ax.scatter(centroids_6[:, 0], centroids_6[:, 1], centroids_6[:, 2], c='red', marker='X', s=200, label='Centroids')
ax.set_title('K-Means Clustering with k=6 (3D)')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')
ax.legend()
plt.show()
print(f"Silhouette Score for k=6: {score_6}")
# Out:
# Silhouette Score for k=6: 0.5474455877911045

# %%
silhouette_scores = []

for k in range(2, 7):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data) 
    labels = kmeans.labels_
    score = silhouette_score(data, labels)  
    silhouette_scores.append(score)

plt.figure(figsize=(8, 6))
plt.plot(range(2, 7), silhouette_scores, marker='o', linestyle='-', color='b')
plt.title('Silhouette Score for K-Means Clustering (k=2 to k=6)')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.xticks(range(2, 7))
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

Z = linkage(data, method='ward')

plt.figure(figsize=(14, 10), dpi=120)
dendrogram(
    Z,
    labels=data.index.astype(str),  
    orientation='top',              
    leaf_font_size=10,            
    truncate_mode='lastp',          
    p=30                           
)
plt.title('Hierarchical Clustering Dendrogram', fontsize=14)
plt.xlabel('Distance', fontsize=12)
plt.ylabel('Data Point Index', fontsize=12)
plt.tight_layout()
plt.show()

max_d = 7.0  
clusters = fcluster(Z, max_d, criterion='distance')
if len(set(clusters)) > 1:
    score = silhouette_score(data, clusters)
    print("Silhouette Score for Hierarchical Clustering:", score)
else:
    print("Not enough clusters to compute the silhouette score.")
# Out:
# Silhouette Score for Hierarchical Clustering: 0.4152517792430545

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=0.5, min_samples=5) 
clusters = dbscan.fit_predict(data)
data['cluster'] = clusters
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

unique_clusters = np.unique(clusters)
for cluster in unique_clusters:
    mask = clusters == cluster
    label = f"Cluster {cluster}" if cluster != -1 else "Noise"
    ax.scatter(data[mask].iloc[:, 0], data[mask].iloc[:, 1], data[mask].iloc[:, 2], label=label)

ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
ax.set_zlabel('Component 3')
ax.set_title('DBSCAN Clustering in 3D')

plt.show()
cluster_labels = clusters[clusters != -1]  
if len(np.unique(cluster_labels)) > 1:
    score = silhouette_score(data[clusters != -1], cluster_labels)
    print("Silhouette Score (excluding noise):", score)
else:
    print("Not enough clusters (excluding noise) to compute a silhouette score.")
# Out:
# Silhouette Score (excluding noise): 0.7699301529992981
